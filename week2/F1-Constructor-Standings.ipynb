# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
columns = []
column_check = False
constructor_dataframe = pd.DataFrame()

# %%
for year in range(1958,2022):
    url = f'https://www.formula1.com/en/results.html/{year}/team.html'
    pageReq = requests.get(url)
    bSoup = BeautifulSoup(pageReq.text, 'lxml')
    raw_data = bSoup.find("table", class_="resultsarchive-table")
    
    if(not column_check):
        for column_name in raw_data.find_all("th"):
            if(len(column_name.text)==0):
                continue
            else:
                item = column_name.text
                columns.append(item)
        column_check = True
        columns.append('Year')
        constructor_dataframe = pd.DataFrame(columns=columns)
    
    for data in raw_data.find_all('tr')[1:]:
        row_data = data.find_all('td')
        row_data = [i.text for i in row_data]
        row_data.pop()
        row_data.pop(0)
        row_data = [x.replace("\n"," ") for x in row_data]
        row_data = [y.strip() for y in row_data]
        year_info = bSoup.find("h1", class_="ResultsArchiveTitle")
        year_info = year_info.text
        year_info = year_info.replace("\n", " ").strip()
        row_data.append(year_info)
        constructor_dataframe.loc[len(constructor_dataframe)] = row_data

# %%
constructor_dataframe.head(25)
# Out:
#    Pos                Team PTS                        Year
# 0    1             Vanwall  48  1958 Constructor Standings
# 1    2             Ferrari  40  1958 Constructor Standings
# 2    3       Cooper Climax  31  1958 Constructor Standings
# 3    4                 BRM  18  1958 Constructor Standings
# 4    5            Maserati   6  1958 Constructor Standings
# 5    6        Lotus Climax   3  1958 Constructor Standings
# 6    1       Cooper Climax  40  1959 Constructor Standings
# 7    2             Ferrari  32  1959 Constructor Standings
# 8    3                 BRM  18  1959 Constructor Standings
# 9    4        Lotus Climax   5  1959 Constructor Standings
# 10   1       Cooper Climax  48  1960 Constructor Standings
# 11   2        Lotus Climax  34  1960 Constructor Standings
# 12   3             Ferrari  26  1960 Constructor Standings
# 13   4                 BRM   8  1960 Constructor Standings
# 14   5     Cooper Maserati   3  1960 Constructor Standings
# 15   6  Cooper Castellotti   3  1960 Constructor Standings
# 16   1             Ferrari  40  1961 Constructor Standings
# 17   2        Lotus Climax  32  1961 Constructor Standings
# 18   3             Porsche  22  1961 Constructor Standings
# 19   4       Cooper Climax  14  1961 Constructor Standings
# 20   5          BRM Climax   7  1961 Constructor Standings
# 21   1                 BRM  42  1962 Constructor Standings
# 22   2        Lotus Climax  36  1962 Constructor Standings
# 23   3       Cooper Climax  29  1962 Constructor Standings
# 24   4         Lola Climax  19  1962 Constructor Standings

# %%
constructor_dataframe.tail(25)
# Out:
#     Pos                       Team    PTS                        Year
# 640   6  Scuderia Toro Rosso Honda     85  2019 Constructor Standings
# 641   7  Racing Point BWT Mercedes     73  2019 Constructor Standings
# 642   8  Alfa Romeo Racing Ferrari     57  2019 Constructor Standings
# 643   9               Haas Ferrari     28  2019 Constructor Standings
# 644  10          Williams Mercedes      1  2019 Constructor Standings
# 645   1                   Mercedes    573  2020 Constructor Standings
# 646   2      Red Bull Racing Honda    319  2020 Constructor Standings
# 647   3            McLaren Renault    202  2020 Constructor Standings
# 648   4  Racing Point BWT Mercedes    195  2020 Constructor Standings
# 649   5                    Renault    181  2020 Constructor Standings
# 650   6                    Ferrari    131  2020 Constructor Standings
# 651   7           AlphaTauri Honda    107  2020 Constructor Standings
# 652   8  Alfa Romeo Racing Ferrari      8  2020 Constructor Standings
# 653   9               Haas Ferrari      3  2020 Constructor Standings
# 654  10          Williams Mercedes      0  2020 Constructor Standings
# 655   1                   Mercedes  613.5  2021 Constructor Standings
# 656   2      Red Bull Racing Honda  585.5  2021 Constructor Standings
# 657   3                    Ferrari  323.5  2021 Constructor Standings
# 658   4           McLaren Mercedes    275  2021 Constructor Standings
# 659   5             Alpine Renault    155  2021 Constructor Standings
# 660   6           AlphaTauri Honda    142  2021 Constructor Standings
# 661   7      Aston Martin Mercedes     77  2021 Constructor Standings
# 662   8          Williams Mercedes     23  2021 Constructor Standings
# 663   9  Alfa Romeo Racing Ferrari     13  2021 Constructor Standings
# 664  10               Haas Ferrari      0  2021 Constructor Standings

# %%
constructor_dataframe.shape
# Out:
# (665, 4)

# %%
constructor_dataframe.to_csv('F1_Constructor_Standings.csv', header= True, index= False)
